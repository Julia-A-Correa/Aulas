# %%
palavra = input("A palavra escolhida é ")
for letra in palavra:
  palavra = palavra.lower()
len(palavra)
print(palavra.count("a"))
print(palavra.count("e"))
print(palavra.count("i"))
print(palavra.count("o"))
print(palavra.count("u"))
# Out:
# A palavra escolhida é Amigo
# 1
# 0
# 1
# 1
# 0

# %%
soma = 0
numeros = range(1,500)
i = 0
while soma < 500:
  soma += numeros[i]
  i += 1
  print(soma)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528

# %%
soma = 0
x = 0
for num in
while x < 20:
  x+=1
  if x%4==0:
    print(x)
    soma +=x
  else:
    if x%5==0:
      pass
    else:
      print("buscando... ")
      continue

  if soma>300:
    print(soma)
    break

# %%
for n in range(1, 21):
    if n % 4 == 0:
        continue
    if n == 17:
        break
    print(n)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 9
# 10
# 11
# 13
# 14
# 15

# %% [markdown]
# Desafio da aula 5(Consegui fazer apenas 1 dos desafios):👇🏻

# %%
n = int(input("Digite um número de 1 a 10: "))
if 1 <= n <= 10:
    print(f"\n🔢 Tabuada do {n}:")
    for i in range(1, 11):
        resultado = n * i
        print(f"{n} x {i} = {resultado}")
else:
    print("Número inválido! Digite um valor entre 1 e 10.")
# Out:
# Digite um número de 1 a 10: 7
#
# 🔢 Tabuada do 7:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
